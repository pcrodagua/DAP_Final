# %%
import seaborn as sns
import pandas as pd
import numpy as np

sns.set_style("ticks")
# %matplotlib inline

# %%
anemia_df = pd.read_csv('../data/clean/anemia_balanced_clean.csv', index_col=False)
x_values = anemia_df.drop(columns=["ANEMIA"])
x_values = anemia_df[['INTP', 'SEXO', 'EST_URB', 'EST_MARG', 'HB']]
y_values = anemia_df["ANEMIA"]

# %%
target_count = anemia_df.SEXO.value_counts()
print('Proportion:', round(target_count[0] / target_count[1], 2), ': 1')
target_count.plot(kind='bar', title='Count (Anemia)');

# %%
target_count = anemia_df.EST_URB.value_counts()
#print('Proportion:', round(target_count[0] / target_count[1], 2), ': 1')
target_count.plot(kind='bar', title='Count (Anemia)');

# %%
target_count = anemia_df.EST_MARG.value_counts()
#print('Proportion:', round(target_count[0] / target_count[1], 2), ': 1')
target_count.plot(kind='bar', title='Conteo (Estatus Marginal)');

# %%
target_count = anemia_df.HB.value_counts()
#print('Proportion:', round(target_count[0] / target_count[1], 2), ': 1')
target_count.plot(kind='bar', title='Count (HB)');
