# %%
import matplotlib.pyplot as plt

import seaborn as sns
import pandas as pd
import numpy as np

sns.set_style("ticks")
# %matplotlib inline

# %%
anemia_balanced_pres = pd.read_csv('../data/clean/anemia_balanced_pres.csv', index_col=False)
anemia_balanced_pres.head()
# Out:
#    AFILIACI  AGEB  ALTITUD  ANEMIA  AREA CODE_UPM       EDAD  EDADDIAS  \
# 0         2  0151    387.0     0.0     1    M3010   8.563997    3128.0
# 1         6  0155   1703.0     0.0     1    M1733   6.737850    2461.0
# 2         0  0889     30.0     0.0     2    M0406   9.585215    3501.0
# 3         0  1222     33.0     0.0     1    M2829   9.210130    3364.0
# 4         8   207   2240.0     0.0     1    R1522  14.182067    5180.0
#
#    EDOFISIO  ENTIDAD  ...   MUNICI                          NOM_ENT  \
# 0       NaN       30  ...       53  Veracruz de Ignacio de la Llave
# 1       NaN       17  ...       20                          Morelos
# 2       NaN        4  ...        2                         Campeche
# 3       NaN       28  ...       32                       Tamaulipas
# 4       0.0       15  ...      122                         Mï¿½xico
#
#              NOM_LOC                      NOM_MUN  NSEDECIL  NSEQUINT  \
# 0         Cuitláhuac                   Cuitláhuac         9         5
# 1          Tepoztlán                    Tepoztlán         4         2
# 2  Alfredo V. Bonfil                     Campeche         4         2
# 3            Reynosa                      Reynosa         7         4
# 4               Xico  Valle de Chalco Solidaridad         6         3
#
#    NSETERCI    PONDEF  REGION  SEXO
# 0         3  5121.939       4     1
# 1         2   970.838       2     1
# 2         1   155.232       4     2
# 3         2  1576.740       1     1
# 4         2  3079.646       3     2
#
# [5 rows x 34 columns]

# %%
anemia_balanced_pres.tail()
# Out:
#       AFILIACI AGEB  ALTITUD  ANEMIA  AREA CODE_UPM       EDAD  EDADDIAS  \
# 5363         6  116   2389.0     1.0     2    M3230  17.330595    6330.0
# 5364         6  135   2139.0     1.0     2    M3231  12.881587    4705.0
# 5365         6   60   1843.0     1.0     2    M3236  18.822724    6875.0
# 5366         1  146   1697.0     1.0     1    M3240  13.311430    4862.0
# 5367         1  125   2533.0     1.0     2    M3241  19.572895    7149.0
#
#       EDOFISIO  ENTIDAD  ...   MUNICI    NOM_ENT  \
# 5363       0.0       32  ...       38  Zacatecas
# 5364       0.0       32  ...       38  Zacatecas
# 5365       0.0       32  ...       41  Zacatecas
# 5366       0.0       32  ...       48  Zacatecas
# 5367       0.0       32  ...       50  Zacatecas
#
#                                NOM_LOC                           NOM_MUN  \
# 5363                 El Chiquihuitillo                             Pinos
# 5364              Huertas del Mezquite                             Pinos
# 5365                       Clavellinas                       El Salvador
# 5366  Tlaltenango de Sï¿½nchez Romï¿½n  Tlaltenango de Sï¿½nchez Romï¿½n
# 5367                        Vetagrande                        Vetagrande
#
#       NSEDECIL  NSEQUINT  NSETERCI   PONDEF  REGION  SEXO
# 5363         3         2         1  965.969       2     2
# 5364         4         2         2  243.837       2     2
# 5365         2         1         1  136.947       2     2
# 5366         9         5         3  478.898       2     2
# 5367         9         5         3  503.661       2     2
#
# [5 rows x 34 columns]

# %%
drop_columns = ['FOLIO_C',  'NOM_ENT',  'NOM_MUN', 'NOM_LOC', 
                'FECHA_NA', 'FECHA_VI', 'EST_DIS', 'NSEDECIL',
                'NSEQUINT', 'NSETERCI', 'HEMCAP',  'EDOFISIO',
                'EDAD',     'MESES',    'EST_VAR', 'HBAJUSTA', 
                'CODE_UPM', 'AGEB']
anemia_balanced_pres = anemia_balanced_pres.drop(drop_columns, axis=1)

# %%
anemia_balanced_pres.head()
# Out:
#    AFILIACI  ALTITUD  ANEMIA  AREA  EDADDIAS  ENTIDAD  EST_MARG  EST_URB  \
# 0         2    387.0     0.0     1    3128.0       30       1.0      2.0
# 1         6   1703.0     0.0     1    2461.0       17       1.0      3.0
# 2         0     30.0     0.0     2    3501.0        4       1.0      1.0
# 3         0     33.0     0.0     1    3364.0       28       1.0      3.0
# 4         8   2240.0     0.0     1    5180.0       15       1.0      3.0
#
#      HB   INDICEF  INTP  LOCALI  MUNICI    PONDEF  REGION  SEXO
# 0  12.0  1.672565     5       1      53  5121.939       4     1
# 1  13.7 -0.611632     5       1      20   970.838       2     1
# 2  14.1 -0.749564     4     110       2   155.232       4     2
# 3  14.2  0.685656     3       1      32  1576.740       1     1
# 4  16.5  0.386716     3       1     122  3079.646       3     2

# %%
sns.pairplot(anemia_balanced_pres, hue='ANEMIA', vars=['INTP', 'ENTIDAD',  'MUNICI', 'ALTITUD', 'SEXO'])

# %%
plt.figure(figsize=(20,10))
sns.heatmap(anemia_balanced_pres.corr(), annot=True)

# %% [markdown]
# # Feature Selection

# %%
#Correlation with output variable
cor_target = abs(anemia_balanced_pres["ANEMIA"])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.5]
relevant_features.head()
# Out:
# 2684    1.0
# 2685    1.0
# 2686    1.0
# 2687    1.0
# 2688    1.0
# Name: ANEMIA, dtype: float64

# %%
anemia_balanced_pres.to_csv('../data/clean/anemia_balanced_clean.csv', index=False)
anemia_balanced_pres.head()
# Out:
#    AFILIACI  ALTITUD  ANEMIA  AREA  EDADDIAS  ENTIDAD  EST_MARG  EST_URB  \
# 0         2    387.0     0.0     1    3128.0       30       1.0      2.0
# 1         6   1703.0     0.0     1    2461.0       17       1.0      3.0
# 2         0     30.0     0.0     2    3501.0        4       1.0      1.0
# 3         0     33.0     0.0     1    3364.0       28       1.0      3.0
# 4         8   2240.0     0.0     1    5180.0       15       1.0      3.0
#
#      HB   INDICEF  INTP  LOCALI  MUNICI    PONDEF  REGION  SEXO
# 0  12.0  1.672565     5       1      53  5121.939       4     1
# 1  13.7 -0.611632     5       1      20   970.838       2     1
# 2  14.1 -0.749564     4     110       2   155.232       4     2
# 3  14.2  0.685656     3       1      32  1576.740       1     1
# 4  16.5  0.386716     3       1     122  3079.646       3     2

# %%
anemia_balanced_pres.dtypes
# Out:
# AFILIACI      int64
# ALTITUD     float64
# ANEMIA      float64
# AREA          int64
# EDADDIAS    float64
# ENTIDAD       int64
# EST_MARG    float64
# EST_URB     float64
# HB          float64
# INDICEF     float64
# INTP          int64
# LOCALI        int64
# MUNICI        int64
# PONDEF      float64
# REGION        int64
# SEXO          int64
# dtype: object

# %%
#anemia_balanced_pres['AGEB'] = anemia_balanced_pres['AGEB'].apply(pd.to_numeric)

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
x_values = anemia_balanced_pres.drop(columns=["ANEMIA"])
y_values = anemia_balanced_pres["ANEMIA"]
# feature ex_valuestraction
fit = SelectKBest(score_func=f_classif, k=4).fit(x_values, y_values)
# summarize scores
np.set_printoptions(precision=3)
print(fit.scores_)
features = fit.transform(x_values)
# summarize selected features
print(features[0:5,:])
# Out:
# [  3.618e+00   1.301e+02   3.497e-01   1.314e+02   5.772e+00   9.819e+00
#    1.174e+00   8.171e+03   4.297e+01   1.428e+01   2.393e+00   1.901e-01
#    1.008e+01   2.280e+01   2.132e+01]
# [[  3.870e+02   3.128e+03   1.200e+01   1.673e+00]
#  [  1.703e+03   2.461e+03   1.370e+01  -6.116e-01]
#  [  3.000e+01   3.501e+03   1.410e+01  -7.496e-01]
#  [  3.300e+01   3.364e+03   1.420e+01   6.857e-01]
#  [  2.240e+03   5.180e+03   1.650e+01   3.867e-01]]
