# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn import linear_model
from sklearn import datasets
from math import sqrt

import matplotlib.pyplot as plt
import statsmodels.api as sm
import scipy.optimize as opt
from scipy import stats
import seaborn as sns
import pandas as pd
import numpy as np

sns.set_style("ticks")
# %matplotlib inline

# %%
anemia_df = pd.read_csv('../data/clean/anemia_balanced_clean.csv', index_col=False)
from sklearn.utils import resample
anemia_df
# Out:
#       INTP  ENTIDAD  MUNICI  LOCALI  ALTITUD  SEXO  EDADDIAS  EST_URB  \
# 0        3       16     112     159   2440.0     1    1122.0      1.0
# 1        7       24      14      33    342.0     1     695.0      1.0
# 2        5       26      33      85     49.0     1    1039.0      1.0
# 3        6       15      14      46   2495.0     2    1352.0      1.0
# 4        9       27       8      16     40.0     1     665.0      2.0
# 5        5       24      28       1   1864.0     1     609.0      3.0
# 6        4        5      33      79   1110.0     1     487.0      1.0
# 7        4       11      11      43   1736.0     2     793.0      1.0
# 8        5       24      35       1   1849.0     2    1315.0      3.0
# 9        7       24      17      42   1182.0     2    1500.0      1.0
# 10       8       31     102      77     30.0     1    1563.0      2.0
# 11       3       13       8       1   2488.0     2     719.0      2.0
# ...

# %%
from sklearn.utils import resample
boot = resample(anemia_df, replace=True, n_samples=200, random_state=1)
oob = [x for x in anemia_df if x not in boot]
boot.to_csv('../data/clean/anemia_bootstraped.csv',index=False)
