# %%
import pandas as pd

# %%
DEMO_H_DF = pd.read_csv('/home/ospcx/GitProyects/DAP_Final/data/messy/DEMO_H.csv', index_col=False)
DEMO_H_DF.head()
# Out:
#       SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0  73557.0       8.0       2.0       1.0      69.0       NaN       4.0
# 1  73558.0       8.0       2.0       1.0      54.0       NaN       3.0
# 2  73559.0       8.0       2.0       1.0      72.0       NaN       3.0
# 3  73560.0       8.0       2.0       1.0       9.0       NaN       3.0
# 4  73561.0       8.0       2.0       2.0      73.0       NaN       3.0
#
#    RIDRETH3  RIDEXMON  RIDEXAGM    ...     DMDHREDU  DMDHRMAR  DMDHSEDU  \
# 0       4.0       1.0       NaN    ...          3.0       4.0       NaN
# 1       3.0       1.0       NaN    ...          3.0       1.0       1.0
# 2       3.0       2.0       NaN    ...          4.0       1.0       3.0
# 3       3.0       1.0     119.0    ...          3.0       1.0       4.0
# 4       3.0       1.0       NaN    ...          5.0       1.0       5.0
#
#        WTINT2YR      WTMEC2YR  SDMVPSU  SDMVSTRA  INDHHIN2  INDFMIN2  INDFMPIR
# ...

# %%
DEMO_H_DF.isnull().mean()
# Out:
# SEQN        0.000000
# SDDSRVYR    0.000000
# RIDSTATR    0.000000
# RIAGENDR    0.000000
# RIDAGEYR    0.000000
# RIDAGEMN    0.933857
# RIDRETH1    0.000000
# RIDRETH3    0.000000
# RIDEXMON    0.035577
# RIDEXAGM    0.585946
# DMQMILIZ    0.384668
# DMQADFC     0.946634
# DMDBORN4    0.000000
# DMDCITZN    0.000393
# DMDYRSUS    0.812482
# DMDEDUC3    0.724521
# DMDEDUC2    0.433022
# DMDMARTL    0.433022
# RIDEXPRG    0.871351
# SIALANG     0.000000
# SIAPROXY    0.000098
# SIAINTRP    0.000000
# FIALANG     0.011892
# FIAPROXY    0.011892
# FIAINTRP    0.011892
# MIALANG     0.281474
# MIAPROXY    0.281376
# MIAINTRP    0.281278
# AIALANGA    0.379165
# DMDHHSIZ    0.000000
# DMDFMSIZ    0.000000
# DMDHHSZA    0.000000
# DMDHHSZB    0.000000
# DMDHHSZE    0.000000
# DMDHRGND    0.000000
# DMDHRAGE    0.000000
# DMDHRBR4    0.029189
# DMDHREDU    0.028894
# DMDHRMAR    0.012088
# DMDHSEDU    0.474988
# WTINT2YR    0.000000
# WTMEC2YR    0.000000
# SDMVPSU     0.000000
# ...

# %%
DEMO_H_DF = DEMO_H_DF.drop(columns=['RIDAGEMN', 'DMQADFC', 'DMDYRSUS', 'RIDEXPRG'])

# %%
DEMO_H_DF.to_csv('DEMO_H_T.csv', index=False)

# %%
is_hispanic = DEMO_H_DF[(DEMO_H_DF.RIDRETH1 == 1) | (DEMO_H_DF.RIDRETH1 == 2)] 
is_hispanic.head()
# Out:
#        SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDRETH1  RIDRETH3  \
# 5   73562.0       8.0       2.0       1.0      56.0       1.0       1.0
# 8   73565.0       8.0       1.0       1.0      42.0       2.0       2.0
# 20  73577.0       8.0       2.0       1.0      32.0       1.0       1.0
# 21  73578.0       8.0       2.0       1.0      18.0       1.0       1.0
# 33  73590.0       8.0       2.0       1.0       2.0       1.0       1.0
#
#     RIDEXMON  RIDEXAGM  DMQMILIZ    ...     DMDHREDU  DMDHRMAR  DMDHSEDU  \
# 5        1.0       NaN       1.0    ...          4.0       3.0       NaN
# 8        NaN       NaN       2.0    ...          3.0       1.0       5.0
# 20       1.0       NaN       2.0    ...          3.0       6.0       NaN
# 21       1.0     218.0       2.0    ...          3.0       1.0       1.0
# 33       1.0      30.0       NaN    ...          4.0       1.0       4.0
#
#         WTINT2YR      WTMEC2YR  SDMVPSU  SDMVSTRA  INDHHIN2  INDFMIN2  \
# ...

# %%
is_hispanic.tail()
# Out:
#           SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDRETH1  RIDRETH3  \
# 10168  83725.0       8.0       2.0       1.0       7.0       1.0       1.0
# 10169  83726.0       8.0       2.0       1.0      40.0       1.0       1.0
# 10170  83727.0       8.0       2.0       1.0      26.0       2.0       2.0
# 10171  83728.0       8.0       2.0       2.0       2.0       1.0       1.0
# 10173  83730.0       8.0       2.0       1.0       7.0       2.0       2.0
#
#        RIDEXMON  RIDEXAGM  DMQMILIZ    ...     DMDHREDU  DMDHRMAR  DMDHSEDU  \
# 10168       1.0      95.0       NaN    ...          4.0       4.0       NaN
# 10169       1.0       NaN       2.0    ...          1.0       3.0       NaN
# 10170       2.0       NaN       2.0    ...          3.0       NaN       NaN
# 10171       2.0      24.0       NaN    ...          3.0       1.0       3.0
# 10173       1.0      84.0       NaN    ...          4.0       1.0       3.0
#
# ...

# %%
is_hispanic.shape
# Out:
# (2690, 43)

# %%
is_hispanic3 = DEMO_H_DF[(DEMO_H_DF.RIDRETH3 == 1) | (DEMO_H_DF.RIDRETH3 == 2)] 
is_hispanic3.head()
# Out:
#        SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDRETH1  RIDRETH3  \
# 5   73562.0       8.0       2.0       1.0      56.0       1.0       1.0
# 8   73565.0       8.0       1.0       1.0      42.0       2.0       2.0
# 20  73577.0       8.0       2.0       1.0      32.0       1.0       1.0
# 21  73578.0       8.0       2.0       1.0      18.0       1.0       1.0
# 33  73590.0       8.0       2.0       1.0       2.0       1.0       1.0
#
#     RIDEXMON  RIDEXAGM  DMQMILIZ    ...     DMDHREDU  DMDHRMAR  DMDHSEDU  \
# 5        1.0       NaN       1.0    ...          4.0       3.0       NaN
# 8        NaN       NaN       2.0    ...          3.0       1.0       5.0
# 20       1.0       NaN       2.0    ...          3.0       6.0       NaN
# 21       1.0     218.0       2.0    ...          3.0       1.0       1.0
# 33       1.0      30.0       NaN    ...          4.0       1.0       4.0
#
#         WTINT2YR      WTMEC2YR  SDMVPSU  SDMVSTRA  INDHHIN2  INDFMIN2  \
# ...

# %%
is_hispanic3.tail()
# Out:
#           SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDRETH1  RIDRETH3  \
# 10168  83725.0       8.0       2.0       1.0       7.0       1.0       1.0
# 10169  83726.0       8.0       2.0       1.0      40.0       1.0       1.0
# 10170  83727.0       8.0       2.0       1.0      26.0       2.0       2.0
# 10171  83728.0       8.0       2.0       2.0       2.0       1.0       1.0
# 10173  83730.0       8.0       2.0       1.0       7.0       2.0       2.0
#
#        RIDEXMON  RIDEXAGM  DMQMILIZ    ...     DMDHREDU  DMDHRMAR  DMDHSEDU  \
# 10168       1.0      95.0       NaN    ...          4.0       4.0       NaN
# 10169       1.0       NaN       2.0    ...          1.0       3.0       NaN
# 10170       2.0       NaN       2.0    ...          3.0       NaN       NaN
# 10171       2.0      24.0       NaN    ...          3.0       1.0       3.0
# 10173       1.0      84.0       NaN    ...          4.0       1.0       3.0
#
# ...

# %%
is_hispanic3.shape
# Out:
# (2690, 43)

# %%
is_hispanic_d = DEMO_H_DF[
    (DEMO_H_DF.RIDRETH1 == 1) | (DEMO_H_DF.RIDRETH1 == 1) | 
    (DEMO_H_DF.RIDRETH1 == 2) | (DEMO_H_DF.RIDRETH1 == 2) |
    (DEMO_H_DF.RIDRETH3 == 1) | (DEMO_H_DF.RIDRETH3 == 1) | 
    (DEMO_H_DF.RIDRETH1 == 2) | (DEMO_H_DF.RIDRETH3 == 2) ] 
is_hispanic_d.head()
# Out:
#        SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDRETH1  RIDRETH3  \
# 5   73562.0       8.0       2.0       1.0      56.0       1.0       1.0
# 8   73565.0       8.0       1.0       1.0      42.0       2.0       2.0
# 20  73577.0       8.0       2.0       1.0      32.0       1.0       1.0
# 21  73578.0       8.0       2.0       1.0      18.0       1.0       1.0
# 33  73590.0       8.0       2.0       1.0       2.0       1.0       1.0
#
#     RIDEXMON  RIDEXAGM  DMQMILIZ    ...     DMDHREDU  DMDHRMAR  DMDHSEDU  \
# 5        1.0       NaN       1.0    ...          4.0       3.0       NaN
# 8        NaN       NaN       2.0    ...          3.0       1.0       5.0
# 20       1.0       NaN       2.0    ...          3.0       6.0       NaN
# 21       1.0     218.0       2.0    ...          3.0       1.0       1.0
# 33       1.0      30.0       NaN    ...          4.0       1.0       4.0
#
#         WTINT2YR      WTMEC2YR  SDMVPSU  SDMVSTRA  INDHHIN2  INDFMIN2  \
# ...

# %%
is_hispanic_d.shape
# Out:
# (2690, 43)

# %%
is_hispanic_d.to_csv('DEMO_H_HISP.csv', index=False)

# %%
is_hispanic_d.isnull().mean()
# Out:
# SEQN        0.000000
# SDDSRVYR    0.000000
# RIDSTATR    0.000000
# RIAGENDR    0.000000
# RIDAGEYR    0.000000
# RIDRETH1    0.000000
# RIDRETH3    0.000000
# RIDEXMON    0.027881
# RIDEXAGM    0.490706
# DMQMILIZ    0.465799
# DMDBORN4    0.000000
# DMDCITZN    0.001115
# DMDEDUC3    0.662825
# DMDEDUC2    0.526022
# DMDMARTL    0.526022
# SIALANG     0.000000
# SIAPROXY    0.000372
# SIAINTRP    0.000000
# FIALANG     0.013011
# FIAPROXY    0.013011
# FIAINTRP    0.013011
# MIALANG     0.306691
# MIAPROXY    0.306691
# MIAINTRP    0.306691
# AIALANGA    0.357249
# DMDHHSIZ    0.000000
# DMDFMSIZ    0.000000
# DMDHHSZA    0.000000
# DMDHHSZB    0.000000
# DMDHHSZE    0.000000
# DMDHRGND    0.000000
# DMDHRAGE    0.000000
# DMDHRBR4    0.026766
# DMDHREDU    0.026022
# DMDHRMAR    0.015613
# DMDHSEDU    0.423048
# WTINT2YR    0.000000
# WTMEC2YR    0.000000
# SDMVPSU     0.000000
# SDMVSTRA    0.000000
# INDHHIN2    0.015613
# INDFMIN2    0.013011
# INDFMPIR    0.113383
# ...
